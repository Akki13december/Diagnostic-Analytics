# %%
pip install numpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 51.0 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 77.7 MB/s eta 0:00:0000:010:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 6.4 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 64.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 kB 58.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 31.1 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 83.4 MB/s eta 0:00:00:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install matplotlib

# %%
pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 5.6 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
dataset = pd.read_excel("diabetes - Copy - Copy.xlsx")

# %%
dataset.head(n = 10)
# Out:
#    Gestational Diabetes  Glucose Level  BP(Blood Pressure) level  Prediabetes  \
# 0                     1             85                        96            0
# 1                     3            137                        66          125
# 2                     0            183                       110          120
# 3                     2             78                        40          100
# 4                     4            138                        40          125
# 5                     4             70                        90          120
# 6                     2             70                        70            0
# 7                     0             10                        50            0
# 8                     3            150                       120          120
# 9                     1             10                        50          100
#
#    Insulin level  Physical Activity  Genetic/Family History  Age  Results
# ...

# %%
dataset.tail(n = 10)
# Out:
#     Gestational Diabetes  Glucose Level  BP(Blood Pressure) level  \
# 8                      3            150                       120
# 9                      1             10                        50
# 10                     0            150                       150
# 11                     4            140                       120
# 12                     2             70                        50
# 13                     0             40                        40
# 14                     3            190                       100
# 15                     0            190                       110
# 16                     0             80                        78
# 17                     5            196                       100
#
#     Prediabetes  Insulin level  Physical Activity  Genetic/Family History  \
# 8           120            120                  1                   0.122
# 9           100             10                  4                   0.011
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Gestational Diabetes      18 non-null     int64
#  1   Glucose Level             18 non-null     int64
#  2   BP(Blood Pressure) level  18 non-null     int64
#  3   Prediabetes               18 non-null     int64
#  4   Insulin level             18 non-null     int64
#  5   Physical Activity         18 non-null     int64
#  6   Genetic/Family History    18 non-null     float64
#  7   Age                       18 non-null     int64
#  8   Results                   18 non-null     int64
# dtypes: float64(1), int64(8)
# memory usage: 1.4 KB

# %%
sns.countplot(x='Results', data=dataset, palette='hls')
# Out:
# <AxesSubplot:xlabel='Results', ylabel='count'>

# %%
dataset.groupby('Results').mean()
# Out:
#          Gestational Diabetes  Glucose Level  BP(Blood Pressure) level  \
# Results
# 0                    1.000000      55.500000                 60.666667
# 1                    2.333333     137.833333                 93.000000
#
#          Prediabetes  Insulin level  Physical Activity  \
# Results
# 0               50.0          10.00           3.166667
# 1              107.5         103.75           1.250000
#
#          Genetic/Family History   Age
# Results
# 0                      0.660500  40.5
# 1                      1.688583  49.0

# %%
pip install scikit-learn scipy matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 43.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 36.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 34.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from sklearn import linear_model, datasets, metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc
import math
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset.isnull().sum()
# Out:
# Gestational Diabetes        0
# Glucose Level               0
# BP(Blood Pressure) level    0
# Prediabetes                 0
# Insulin level               0
# Physical Activity           0
# Genetic/Family History      0
# Age                         0
# Results                     0
# dtype: int64

# %%
sns.boxplot(x='Results', y='Physical Activity', data=dataset, palette='hls')
# Out:
# <AxesSubplot:xlabel='Results', ylabel='Physical Activity'>

# %%
sns.boxplot(x='Results', y='Genetic/Family History', data=dataset, palette='hls')
# Out:
# <AxesSubplot:xlabel='Results', ylabel='Genetic/Family History'>

# %%
sns.boxplot(x='Results', y='Prediabetes', data=dataset, palette='hls')
# Out:
# <AxesSubplot:xlabel='Results', ylabel='Prediabetes'>

# %%
sns.boxplot(x='Results', y='Glucose Level', data=dataset, palette='hls')
# Out:
# <AxesSubplot:xlabel='Results', ylabel='Glucose Level'>

# %%
sns.boxplot(x='Results', y='Age', data=dataset, palette='hls')
# Out:
# <AxesSubplot:xlabel='Results', ylabel='Age'>

# %%
sns.heatmap(dataset.corr())
# Out:
# <AxesSubplot:>
